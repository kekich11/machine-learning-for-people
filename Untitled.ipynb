# %%
print("hello world!")
# Out:
# hello world!

# %%
import matplotlib.pyplot as plt

# %%
1 + 100
# Out:
# 101

# %%
1 + 1
2 + 2
3 + 3
# Out:
# 6

# %%
import numpy as np

# %%
plt.plot(np.sin(range(6)))

# %% [markdown]
# # HEADING 1.
